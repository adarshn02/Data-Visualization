# %%
import matplotlib.pyplot as plt

# %%
data=[12,34,1,56,33,11,15,67]
data
# Out:
# [12, 34, 1, 56, 33, 11, 15, 67]

# %%
plt.plot(data)

# %%
over=[1,2,3,4,5]
runs=[1,7,13,18,20]

# %%
plt.plot(over,runs)

# %%
states=["goa","maha","karna","andhra"]
count=[1200,600,800,1100]
plt.bar(states,count,width=0.5,color=["g","r","b","y"])
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(states,count,label="rear 2020")
plt.bar(states,[1000,300,4321,301],label="2021")
plt.legend()

# %%
import numpy as np
y=np.random.random(25)
y
# Out:
# array([0.80397635, 0.53243667, 0.56197679, 0.76399528, 0.78234808,
#        0.91297106, 0.98776375, 0.66567845, 0.93411639, 0.84196777,
#        0.69497418, 0.14773142, 0.0934684 , 0.46951405, 0.64686455,
#        0.43097675, 0.05314544, 0.32198207, 0.29323013, 0.67945983,
#        0.94045501, 0.99741685, 0.58419744, 0.85793476, 0.11638306])

# %%
x=range(25)
x
# Out:
# range(0, 25)

# %%
plt.scatter(x,y)

# %%
percentage=[91,78,43,56,79,76,88,60,67,89,86,77]
percentage
# Out:
# [91, 78, 43, 56, 79, 76, 88, 60, 67, 89, 86, 77]

# %%
plt.hist(percentage,bins=5,cumulative=True,histtype="step")
# Out:
# (array([ 1.,  3.,  4.,  8., 12.]),
#  array([43. , 52.6, 62.2, 71.8, 81.4, 91. ]),
#  [<matplotlib.patches.Polygon at 0x7f9fb9044850>])

# %%
company=["info","imb","wipro","apple"]
shares=[60,40,65,75]
company,shares
# Out:
# (['info', 'imb', 'wipro', 'apple'], [60, 40, 65, 75])

# %%
plt.pie(shares,autopct="%.f%%",labels=company,radius=1.4,labeldistance=0.7,explode=[0,0,0,0.5])
plt.show()

# %%
plt.subplots(2,3)
plt.tight_layout()

# %%
a=[10,20,30,40,50]
b=[100,200,300,400,500]
plt.figure(figsize=(12,3))
plt.subplot(221)
plt.bar(a,b)

plt.subplot(222)
plt.plot(a,b)

plt.subplot(223)
plt.scatter(a,b)

plt.subplot(224)
plt.plot(a,b)

# %%
import numpy as np
import pandas as pd

# %%
data=np.random.random((5,4))
data
# Out:
# array([[0.16270949, 0.12783882, 0.47674353, 0.54237829],
#        [0.38957214, 0.81722526, 0.96030014, 0.63911174],
#        [0.43702798, 0.20990891, 0.71982549, 0.05272956],
#        [0.47740758, 0.17729834, 0.24965289, 0.67813269],
#        [0.25143394, 0.57158433, 0.33212668, 0.27801882]])

# %%
df=pd.DataFrame(data,columns=list("abcd"))
df
# Out:
#           a         b         c         d
# 0  0.162709  0.127839  0.476744  0.542378
# 1  0.389572  0.817225  0.960300  0.639112
# 2  0.437028  0.209909  0.719825  0.052730
# 3  0.477408  0.177298  0.249653  0.678133
# 4  0.251434  0.571584  0.332127  0.278019

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df[['a','b']].plot
